# %%
from fixtures import get_next_team, draw_scatter, get_fixtures, get_next_fixtures
from fetcher import get_team_data
from team_manipulator import get_teams_stats_table, get_team_form
import pandas as pd
import matplotlib.pyplot as plt

# %%
LAST_GAMEWEEK = 4
CURRENT_GAMEWEEK = 30
START_GAMEWEEK = 31
END_GAMEWEEK = 34

plt.rcParams["figure.figsize"] = (5,5)

# %%
a, b = get_teams_stats_table(teams=get_team_data(), buffer=CURRENT_GAMEWEEK, last_check=LAST_GAMEWEEK, h_a="")
teams = get_team_form(a,b)
teams_df = pd.DataFrame(teams)

# %%
# Get Last Fixtures
fixtures = get_fixtures()
next_fixtures = get_next_fixtures(fixtures=fixtures, start_gw=START_GAMEWEEK, end_gw=END_GAMEWEEK)
next_fixtures_df = pd.DataFrame(next_fixtures)
# Out:
# /Users/adarwawan/Work/fpl2022/fplbot/fixtures.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t_fixture['h/a'] = np.where(t_fixture['team_home'] == index, 'home', 'away')
# /Users/adarwawan/Work/fpl2022/fplbot/fixtures.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t_fixture['opponent'] = np.where(t_fixture['h/a'] == 'home', t_fixture['team_away'], t_fixture['team_home'])
# /Users/adarwawan/Work/fpl2022/fplbot/fixtures.py:56: SettingWithCopyWarning:
# ...

# %%
# Arsenal Next 5
teams = get_next_team(upcoming_match=next_fixtures, index=0)
teams_df_team = teams_df.loc[teams_df['name'].isin(teams)]
draw_scatter(teams_df_team,teams[0])

# %%
# Aston Villa Next 5
teams = get_next_team(upcoming_match=next_fixtures, index=1)
teams_df_team = teams_df.loc[teams_df['name'].isin(teams)]
draw_scatter(teams_df_team,teams[0])

# %%
# Brentford Next 5
teams = get_next_team(upcoming_match=next_fixtures, index=2)
teams_df_team = teams_df.loc[teams_df['name'].isin(teams)]
draw_scatter(teams_df_team,teams[0])

# %%
# Bounermouth Next 5
teams = get_next_team(upcoming_match=next_fixtures, index=3)
teams_df_team = teams_df.loc[teams_df['name'].isin(teams)]
draw_scatter(teams_df_team,teams[0])

# %%
# Brighton Next 5
teams = get_next_team(upcoming_match=next_fixtures, index=4)
teams_df_team = teams_df.loc[teams_df['name'].isin(teams)]
draw_scatter(teams_df_team,teams[0])

# %%
# Chelsea Next 5
teams = get_next_team(upcoming_match=next_fixtures, index=5)
teams_df_team = teams_df.loc[teams_df['name'].isin(teams)]
draw_scatter(teams_df_team,teams[0])

# %%
# Crystal Palace Next 5
teams = get_next_team(upcoming_match=next_fixtures, index=6)
teams_df_team = teams_df.loc[teams_df['name'].isin(teams)]
draw_scatter(teams_df_team,teams[0])

# %%
# Fulham Next 5
teams = get_next_team(upcoming_match=next_fixtures, index=7)
teams_df_team = teams_df.loc[teams_df['name'].isin(teams)]
draw_scatter(teams_df_team,teams[0])

# %%
# Everton Next 5
teams = get_next_team(upcoming_match=next_fixtures, index=8)
teams_df_team = teams_df.loc[teams_df['name'].isin(teams)]
draw_scatter(teams_df_team,teams[0])

# %%
# Leeds Next 5
teams = get_next_team(upcoming_match=next_fixtures, index=9)
teams_df_team = teams_df.loc[teams_df['name'].isin(teams)]
draw_scatter(teams_df_team,teams[0])

# %%
# Leicester Next 5
teams = get_next_team(upcoming_match=next_fixtures, index=10)
teams_df_team = teams_df.loc[teams_df['name'].isin(teams)]
draw_scatter(teams_df_team,teams[0])

# %%
# Liverpool Next 5
teams = get_next_team(upcoming_match=next_fixtures, index=11)
teams_df_team = teams_df.loc[teams_df['name'].isin(teams)]
draw_scatter(teams_df_team,teams[0])

# %%
# Manchester City Next 5
teams = get_next_team(upcoming_match=next_fixtures, index=12)
teams_df_team = teams_df.loc[teams_df['name'].isin(teams)]
draw_scatter(teams_df_team,teams[0])

# %%
# Manchester United Next 5
teams = get_next_team(upcoming_match=next_fixtures, index=13)
teams_df_team = teams_df.loc[teams_df['name'].isin(teams)]
draw_scatter(teams_df_team,teams[0])

# %%
# Newcastle United Next 5
teams = get_next_team(upcoming_match=next_fixtures, index=14)
teams_df_team = teams_df.loc[teams_df['name'].isin(teams)]
draw_scatter(teams_df_team,teams[0])

# %%
# Nottingham Forest Next 5
teams = get_next_team(upcoming_match=next_fixtures, index=15)
teams_df_team = teams_df.loc[teams_df['name'].isin(teams)]
draw_scatter(teams_df_team,teams[0])

# %%
# Southampton Next 5
teams = get_next_team(upcoming_match=next_fixtures, index=16)
teams_df_team = teams_df.loc[teams_df['name'].isin(teams)]
draw_scatter(teams_df_team,teams[0])

# %%
# Tottenham Next 5
teams = get_next_team(upcoming_match=next_fixtures, index=17)
teams_df_team = teams_df.loc[teams_df['name'].isin(teams)]
draw_scatter(teams_df_team,teams[0])

# %%
# West Ham Next 5
teams = get_next_team(upcoming_match=next_fixtures, index=18)
teams_df_team = teams_df.loc[teams_df['name'].isin(teams)]
draw_scatter(teams_df_team,teams[0])

# %%
# Wolves Next 5
teams = get_next_team(upcoming_match=next_fixtures, index=19)
teams_df_team = teams_df.loc[teams_df['name'].isin(teams)]
draw_scatter(teams_df_team,teams[0])
